# %% [markdown]
# # Creador de personajes
# Libreria pandas para crear y guardar el archivo de personajes

# %%
import pandas as pd

# %% [markdown]
# Creamos la lista de las propiedades de los personajes usando un diccionario como base

# %%
# Disadvantage: -1, Normal: 0, Advantage: 2
caracters = {
    "Name": ["Aquarder", "Firesor", "Electder", "Mousebug", "Splant", "Rockdog"],
    "Type": ["Agua", "Fuego", "Eléctrico", "Escarabajo", "Planta", "Roca"],
    "To_fire": [2, 0, 0, -1, -1, 2],
    "To_rock": [2, -1, -1, 2, 2, 0],
    "To_water": [0, -1, 2, 0, 2, -1],
    "To_electric": [-1, 0, 0, -1, 2, 2],
    "To_plant": [-1, 2, -1, 2, 0, -1],
    "To_beetle": [0, 2, 2, 0, -1, 0],
    "Attack_power": [2, 2, 3, 2, 2, 2],
    "Attack_1": ["Aqua-jet", "Llamarada", "Trueno", "Picotazo", "Hoja navaja", "Roca afilada"],
    "Attack_2": ["Cola férrea", "Embestida", "Arañazo", "Embestida", "Mordisco", "Velocidad"],
    "Attack_3": ["Cabezazo", "Mordisco", "Mordisco", "Cabezazo", "Cabezazo", "Cola férrea"],
    "Special": ["Lluvia", "Día soleado", "Campo magnético", "Esporas", "Rayo solar", "Campo de rocas"],
    "Hp": [25, 25, 25, 25, 25, 25],
    "Description": [
        "Activador de potenciador de campo, Solo se puede utilizar una vez cada 3 turnos y dura dos turnos",
        "Activador de potenciador de campo, Solo se puede utilizar una vez cada 3 turnos y dura dos turnos",
        "Activador de potenciador de campo, Solo se puede utilizar una vez cada 3 turnos y dura dos turnos",
        "Activador de potenciador de campo, Solo se puede utilizar una vez cada 3 turnos y dura dos turnos",
        "Activador de potenciador de campo, Solo se puede utilizar una vez cada 3 turnos y dura dos turnos",
        "Activador de potenciador de campo, Solo se puede utilizar una vez cada 3 turnos y dura dos turnos",       
    ],
    "Picture": [
        "data/pictures/aquarder.png",
        "data/pictures/Firesor.png",
        "data/pictures/electder.png",
        "data/pictures/mousebug.png",
        "data/pictures/splant.png",
        "data/pictures/rockdog.png"
    ]
}

# %%
caracters_pd = pd.DataFrame(caracters)
caracters_pd
# Out:
#        Name        Type  To_fire  To_rock  To_water  To_electric  To_plant  \
# 0  Aquarder        Agua        2        2         0           -1        -1
# 1   Firesor       Fuego        0       -1        -1            0         2
# 2  Electder   Eléctrico        0       -1         2            0        -1
# 3  Mousebug  Escarabajo       -1        2         0           -1         2
# 4    Splant      Planta       -1        2         2            2         0
# 5   Rockdog        Roca        2        0        -1            2        -1
#
#    To_beetle  Attack_power      Attack_1     Attack_2     Attack_3  \
# 0          0             2      Aqua-jet  Cola férrea     Cabezazo
# 1          2             2     Llamarada    Embestida     Mordisco
# 2          2             3        Trueno      Arañazo     Mordisco
# 3          0             2      Picotazo    Embestida     Cabezazo
# 4         -1             2   Hoja navaja     Mordisco     Cabezazo
# ...

# %% [markdown]
# Cambiamos el Index para que sea el nombre del personaje

# %%
caracters_pd = caracters_pd.set_index("Name")

caracters_pd
# Out:
#                 Type  To_fire  To_rock  To_water  To_electric  To_plant  \
# Name
# Aquarder        Agua        2        2         0           -1        -1
# Firesor        Fuego        0       -1        -1            0         2
# Electder   Eléctrico        0       -1         2            0        -1
# Mousebug  Escarabajo       -1        2         0           -1         2
# Splant        Planta       -1        2         2            2         0
# Rockdog         Roca        2        0        -1            2        -1
#
#           To_beetle  Attack_power      Attack_1     Attack_2     Attack_3  \
# Name
# Aquarder          0             2      Aqua-jet  Cola férrea     Cabezazo
# Firesor           2             2     Llamarada    Embestida     Mordisco
# Electder          2             3        Trueno      Arañazo     Mordisco
# Mousebug          0             2      Picotazo    Embestida     Cabezazo
# Splant           -1             2   Hoja navaja     Mordisco     Cabezazo
# ...

# %% [markdown]
# Guardamos el archivo como csv

# %%
caracters_pd.to_csv("caracters.csv")

# %%
caracters_pd.columns.tolist()
# Out:
# ['Type',
#  'To_fire',
#  'To_rock',
#  'To_water',
#  'To_electric',
#  'To_plant',
#  'To_beetle',
#  'Attack_power',
#  'Attack_1',
#  'Attack_2',
#  'Attack_3',
#  'Special',
#  'Hp',
#  'Description',
#  'Picture']
